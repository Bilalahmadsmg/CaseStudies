# %%
import pandas as pd
import numpy as np
import re
import spacy
import nltk
import string

# %%
data = pd.read_csv("C:\\Users\\DELL\\Basecamp3\\GLabs_Data_Science_Learn\\Getting_started_with_text_preprocessing\\data\\text.csv")
data.head()
# Out:
#                                                                                                                                                                                             text
# 0                                                                                                                                              @161252 What's that egg website people talk about
# 1                                                                                                                                         Why!🤷🏻‍♀️ #iOS11 @AppleSupport https://t.co/BXrVfeIXxq
# 2  @693975 We can assist you. We recommend updating to iOS 11.1.1 if you haven't had the chance to do so. You can also DM us with the following link for futher support. https://t.co/GDrqU22YpT
# 3                                                                                                     @331912 @115955 Thats better than having an unstable connection that drops every 5-20 mins
# ...

# %%
data = pd.read_csv("C:\\Users\\DELL\\Basecamp3\\GLabs_Data_Science_Learn\\Getting_started_with_text_preprocessing\\data\\text.csv", lineterminator='\n')

# %%
data.head()
# Out:
#                                                                                                                                                                                             text
# 0                                                                                                                                              @161252 What's that egg website people talk about
# 1                                                                                                                                         Why!🤷🏻‍♀️ #iOS11 @AppleSupport https://t.co/BXrVfeIXxq
# 2  @693975 We can assist you. We recommend updating to iOS 11.1.1 if you haven't had the chance to do so. You can also DM us with the following link for futher support. https://t.co/GDrqU22YpT
# 3                                                                                                     @331912 @115955 Thats better than having an unstable connection that drops every 5-20 mins
# ...

# %%
pd.set_option('max_colwidth',700)

# %%
data.head()
# Out:
#                                                                                                                                                                                             text
# 0                                                                                                                                              @161252 What's that egg website people talk about
# 1                                                                                                                                         Why!🤷🏻‍♀️ #iOS11 @AppleSupport https://t.co/BXrVfeIXxq
# 2  @693975 We can assist you. We recommend updating to iOS 11.1.1 if you haven't had the chance to do so. You can also DM us with the following link for futher support. https://t.co/GDrqU22YpT
# 3                                                                                                     @331912 @115955 Thats better than having an unstable connection that drops every 5-20 mins
# ...

# %%
sample_string = data['text'].values[1]

# %%
sample_string
# Out:
# 'Why!🤷🏻\u200d♀️ #iOS11 @AppleSupport https://t.co/BXrVfeIXxq'

# %% [markdown]
# ### Lower casing

# %%
data.isnull().sum()
# Out:
# text    0
# dtype: int64

# %%
data['text'] = data['text'].map(lambda x: x.lower ())

# %%
data.head()
# Out:
#                                                                                                                                                                                             text
# 0                                                                                                                                              @161252 what's that egg website people talk about
# 1                                                                                                                                         why!🤷🏻‍♀️ #ios11 @applesupport https://t.co/bxrvfeixxq
# 2  @693975 we can assist you. we recommend updating to ios 11.1.1 if you haven't had the chance to do so. you can also dm us with the following link for futher support. https://t.co/gdrqu22ypt
# 3                                                                                                     @331912 @115955 thats better than having an unstable connection that drops every 5-20 mins
# ...

# %% [markdown]
# ### Removing punctuations

# %%
puncts = string.punctuation
puncts
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
list(puncts)
# Out:
# ['!',
#  '"',
#  '#',
#  '$',
#  '%',
#  '&',
#  "'",
#  '(',
#  ')',
#  '*',
#  '+',
#  ',',
#  '-',
#  '.',
#  '/',
#  ':',
#  ';',
#  '<',
#  '=',
#  '>',
#  '?',
#  '@',
#  '[',
#  '\\',
#  ']',
#  '^',
#  '_',
#  '`',
#  '{',
#  '|',
#  '}',
#  '~']

# %%
test = "Hey! It\'s me. What\'s up? "
test
# Out:
# "Hey! It's me. What's up? "

# %%
for p in list(puncts):
    test = test.replace(p, "")
print(test)
# Out:
# Hey Its me Whats up

# %%
test1 = "Hey! It\'s me. What\'s up?"
test1
# Out:
# "Hey! It's me. What's up?"

# %%
re.sub("[^d/w/s]", "", test1)
# Out:
# 'ss'

# %%
re.sub("[!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~]", "", sample_string)
# Out:
#   File "<ipython-input-103-eb509a331473>", line 1
#     re.sub("[!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~]", "", sample_string)
#                                                                      ^
# SyntaxError: unexpected EOF while parsing

# %%
for s in sample_string.split():
    print(s.strip(puncts))
# Out:
# Why!🤷🏻‍♀️
# iOS11
# AppleSupport
# https://t.co/BXrVfeIXxq

# %%
def remove_punctualtions(text):
    res = []
    for t in text.split():
        if t.lower().startswith("http"):
            res.append(t)
        else:
            res.append(t.translate(str.maketrans("", "", puncts)))
    return " ".join(res)

# %%
remove_punctualtions(sample_string)
# Out:
# 'Why🤷🏻\u200d♀️ iOS11 AppleSupport https://t.co/BXrVfeIXxq'

# %%
data['text'] = data['text'].map(remove_punctualtions)
data.head()
# Out:
#                                                                                                                                                                                      text
# 0                                                                                                                                         161252 whats that egg website people talk about
# 1                                                                                                                                     why🤷🏻‍♀️ ios11 applesupport https://t.co/bxrvfeixxq
# 2  693975 we can assist you we recommend updating to ios 1111 if you havent had the chance to do so you can also dm us with the following link for futher support https://t.co/gdrqu22ypt
# 3                                                                                                 331912 115955 thats better than having an unstable connection that drops every 520 mins
# ...

# %%
import nltk

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %% [markdown]
# ### StopWords Removal

# %%
from nltk.corpus import stopwords

# %%
stw = stopwords.words("English")
stw
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
def remove_stopwords(text):
    print (text)
    
    res = []
    
    for w in text.split():
        if w.lower not in stw:
            res.append(w)
            
    return " ".join(res)

# %%
remove_stopwords('I am not coming home')
# Out:
# I am not coming home
# 'I am not coming home'

# %%
data['text']
# Out:
# 0                                                                                                                                              161252 whats that egg website people talk about
# 1                                                                                                                                          why🤷🏻‍♀️ ios11 applesupport https://t.co/bxrvfeixxq
# 2       693975 we can assist you we recommend updating to ios 1111 if you havent had the chance to do so you can also dm us with the following link for futher support https://t.co/gdrqu22ypt
# 3                                                                                                      331912 115955 thats better than having an unstable connection that drops every 520 mins
# 4                                                                                                                      virginamerica is probably one of the best airlines ive ever experienced
# ...

# %%
data['text'] = data['text'].map(remove_stopwords)
# Out:
# 161252 whats that egg website people talk about
# why🤷🏻‍♀️ ios11 applesupport https://t.co/bxrvfeixxq
# 693975 we can assist you we recommend updating to ios 1111 if you havent had the chance to do so you can also dm us with the following link for futher support https://t.co/gdrqu22ypt
# 331912 115955 thats better than having an unstable connection that drops every 520 mins
# virginamerica is probably one of the best airlines ive ever experienced
# alaskaair phone system seems to be down
# 325106 cool can you dm us a screenshot of your bank statement rb
# ubersupport reports are there are 68 ubers waiting for passengers something isnt working
# 565060 since our twitter support is available in english get help at https://t.co/ibiy3vmgpj or join https://t.co/pvaoffpbjt
# amazonhelp saw that but only after a labored hunt bigger point though why only usb 20 not expecting you to explain usb standards but is therewill there ever be a 30
# ...

# %%
data.head()
# Out:
#                                                                                                                                                                                      text
# 0                                                                                                                                         161252 whats that egg website people talk about
# 1                                                                                                                                     why🤷🏻‍♀️ ios11 applesupport https://t.co/bxrvfeixxq
# 2  693975 we can assist you we recommend updating to ios 1111 if you havent had the chance to do so you can also dm us with the following link for futher support https://t.co/gdrqu22ypt
# 3                                                                                                 331912 115955 thats better than having an unstable connection that drops every 520 mins
# ...

# %% [markdown]
# ### Removing Frequent words

# %%
from collections import Counter
cnt = Counter()

# %%
for text in data['text'].values:
    for word in text.split():
        cnt[word] += 1
        
cnt.most_common(10)
# Out:
# [('to', 3087),
#  ('the', 2658),
#  ('you', 2246),
#  ('i', 1718),
#  ('a', 1657),
#  ('and', 1549),
#  ('for', 1424),
#  ('your', 1255),
#  ('this', 1032),
#  ('is', 953)]

# %%
most_frequent = [c[0] for c in cnt.most_common(10)]
most_frequent
# Out:
# ['to', 'the', 'you', 'i', 'a', 'and', 'for', 'your', 'this', 'is']

# %%
def remove_frequent_words(text):
    res = []
    
    for w in text.split():
        if w.lower not in most_frequent:
            res.append(w)
    return " ".join(res)

# %%
remove_frequent_words("Hello to the India for you as a For country")
# Out:
# 'Hello to the India for you as a For country'

# %%
data('text') = data('text').map(remove_frequent_words)
data.head()
# Out:
#   File "<ipython-input-125-5fc18802a529>", line 1
#     data('text') = data('text').map(remove_frequent_words)
#     ^
# SyntaxError: cannot assign to function call

# %% [markdown]
# ### Removal of most rare words

# %%
cnt.most_common()[-11:-1]
# Out:
# [('319396', 1),
#  ('gravity', 1),
#  ('reunion', 1),
#  ('407091', 1),
#  ('implementing', 1),
#  ('bricked', 1),
#  ('170844', 1),
#  ('inr1400', 1),
#  ('puma', 1),
#  ('custom', 1)]

# %%
[w for w in cnt.most_common() if w[1] == 1]
# Out:
# [('161252', 1),
#  ('why🤷🏻\u200d♀️', 1),
#  ('https://t.co/bxrvfeixxq', 1),
#  ('693975', 1),
#  ('futher', 1),
#  ('331912', 1),
#  ('unstable', 1),
#  ('520', 1),
#  ('325106', 1),
#  ('68', 1),
#  ('565060', 1),
#  ('https://t.co/pvaoffpbjt', 1),
#  ('labored', 1),
#  ('hunt', 1),
#  ('therewill', 1),
#  ('320829', 1),
#  ('8444018500', 1),
#  ('serviced', 1),
#  ('709739', 1),
#  ('https://t.co/egiaye5jmu', 1),
#  ('comic', 1),
#  ('relief', 1),
#  ('stars', 1),
#  ('347847', 1),
#  ('cloudtail', 1),
#  ('pvt', 1),
#  ('ltd', 1),
#  ('dispatching', 1),
#  ('546646', 1),
#  ('guactober', 1),
#  ('639002', 1),
#  ('targetstyle', 1),
#  ('819705', 1),
#  ('https://t.co/o87onrgtcn.', 1),
#  ('https://t.co/lf4fwtbwzm', 1),
#  ('puk', 1),
#  ('197482', 1),
#  ('brandon', 1),
#  ('larger', 1),
#  ('uberxl', 1),
#  ('ubersuv', 1),
#  ('https://t.co/ipngrz8p6h', 1),
#  ('545098', 1),
#  ('286494', 1),
#  ('fait', 1),
#  ('énormément', 1),
#  ('plaisir', 1),
#  ('133454', 1),
# ...

# %%
rare_words = set([w for w in cnt.most_common() if w[1] == 1])
rare_words
# Out:
# {('displaced', 1),
#  ('cbs', 1),
#  ('“too', 1),
#  ('134569', 1),
#  ('https://t.co/lvha47jkgq.', 1),
#  ('leading', 1),
#  ('171648', 1),
#  ('unlinking', 1),
#  ('pleas', 1),
#  ('https://t.co/k05rdmk3t4', 1),
#  ('338369', 1),
#  ('inr1400', 1),
#  ('517073', 1),
#  ('154116', 1),
#  ('659693', 1),
#  ('effect', 1),
#  ('https://t.co/r3gr2seyqf', 1),
#  ('474356', 1),
#  ('https://t.co/mqvwjbr6nu.', 1),
#  ('website😳hope', 1),
#  ('2736x1824', 1),
#  ('792900', 1),
#  ('769717', 1),
#  ('jiri', 1),
#  ('301539', 1),
#  ('you👍👍👍👍', 1),
#  ('775416', 1),
#  ('548047', 1),
#  ('poisoning', 1),
#  ('481765', 1),
#  ('“are', 1),
#  ('painfully', 1),
#  ('livrés', 1),
#  ('320864', 1),
#  ('270100', 1),
#  ('palace', 1),
#  ('facial', 1),
#  ('304227', 1),
#  ('228706', 1),
#  ('739146', 1),
#  ('472561', 1),
#  ('426490', 1),
#  ('backwards', 1),
#  ('bozhin', 1),
#  ('435556', 1),
#  ('649524', 1),
#  ('doigts', 1),
#  ('😶😶😶', 1),
#  ('bucks', 1),
#  ('thehounds', 1),
# ...

# %%
def remove_rare_words(text):
    
    res = []
    
    for w in text.split():
        if w.lower() not in rare_words:
            res.append(w)
            
    return " ".join(res)

# %%
remove_rare_words("I displaced 659693 for effect")
# Out:
# 'I displaced 659693 for effect'

# %%
data('text') = data('text').map(remove_rare_words)
# Out:
#   File "<ipython-input-140-06e23c49e5d6>", line 1
#     data('text') = data('text').map(remove_rare_words)
#     ^
# SyntaxError: cannot assign to function call
